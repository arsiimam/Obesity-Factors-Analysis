# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## **Importing Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Data Loading**

# %%
# Load Dataset from csv file
df = pd.read_csv('../Data/Obesity_DataSet_raw.csv')

# %% [markdown]
# ## **Dataset Overview**

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %% [markdown]
# ### Dataset Column Descriptions and Aliases
#
# The **Obesity dataset** contains various attributes related to individuals' eating habits, lifestyle, and physical conditions. These factors help in predicting obesity levels. The table below provides a detailed explanation of each column, along with **simplified aliases** that can be used for visualization and analysis. These aliases ensure better readability when creating graphs or reports.
#
#
#
# | Column Name                        | Alias                   | Description |
# |-------------------------------------|-------------------------|-------------|
# | **Gender**                          | `Gender`                | The gender of the individual (`Male` or `Female`). |
# | **Age**                             | `Age`                   | The age of the person (in years). |
# | **Height**                          | `Height`                | The height of the person (in meters). |
# | **Weight**                          | `Weight`                | The weight of the person (in kilograms). |
# | **family_history_with_overweight**  | `Family History`        | Whether the person has a family history of being overweight (`yes` or `no`). |
# | **FAVC**                            | `High Caloric Food`     | Frequent consumption of high-caloric food (`yes` or `no`). |
# | **FCVC**                            | `Vegetable Consumption` | Frequency of vegetable consumption (scale 1-3, higher = more frequent). |
# | **NCP**                             | `Meals Per Day`         | Number of main meals per day. |
# | **CAEC**                            | `Snack Consumption`     | Consumption of food between meals (`no`, `Sometimes`, `Frequently`, `Always`). |
# | **SMOKE**                           | `Smoker`                | Whether the person smokes (`yes` or `no`). |
# | **CH2O**                            | `Water Intake`          | Daily water intake (scale 1-3, higher = more water). |
# | **SCC**                             | `Calorie Monitoring`    | Whether the person monitors their calorie intake (`yes` or `no`). |
# | **FAF**                             | `Physical Activity`     | Physical activity frequency (scale, likely days per week). |
# | **TUE**                             | `Tech Usage`            | Time spent using technology devices (numeric scale). |
# | **CALC**                            | `Alcohol Consumption`   | Alcohol consumption frequency (`no`, `Sometimes`, `Frequently`, `Always`). |
# | **MTRANS**                          | `Transport Mode`        | Mode of transportation (`Walking`, `Bike`, `Motorbike`, `Public Transport`, `Car`). |
# | **NObeyesdad**                      | `Obesity Level`         | Obesity classification (`Insufficient Weight`, `Normal Weight`, `Overweight`, `Obesity Type I-III`). |

# %% [markdown]
# ## **Checking Missing Value**

# %%
# Check missing values in each column
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# ## **Checking Duplicate Data**

# %%
# Count duplicate rows  
df.duplicated().sum()
# Out:
# 24

# %%
# Remove duplicate rows  
df = df.drop_duplicates()

# %%
# Verify no duplicate rows remain  
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **Data Distribution**

# %% [markdown]
# ## **Data Distribution : Gender**

# %%
# Count values for Gender  
gender_counts = df["Gender"].value_counts()  
gender_percent = df["Gender"].value_counts(normalize=True) * 100

# %%
gender_counts
# Out:
# Gender
# Male      1052
# Female    1035
# Name: count, dtype: int64

# %%
gender_percent
# Out:
# Gender
# Male      50.407283
# Female    49.592717
# Name: proportion, dtype: float64

# %%
# Define custom colors
colors = ["#6495ED", "#A9A9A9"]  # Light blue and gray

# Create bar plot with increased height
plt.figure(figsize=(6, 5.5))  # Increase height
ax = sns.barplot(x=gender_counts.index, y=gender_counts.values, hue=gender_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2, p.get_height() + 20),  # Move labels above bars
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Gender Distribution", fontsize=14)

plt.ylim(0, gender_counts.max() * 1.1)  # Extend y-axis limit to give space for labels
plt.show()

# %% [markdown]
# ## **Data Distribution : Age**

# %%
# Get summary statistics for the 'Age' column
df['Age'].describe()
# Out:
# count    2087.000000
# mean       24.353090
# std         6.368801
# min        14.000000
# 25%        19.915937
# 50%        22.847618
# 75%        26.000000
# max        61.000000
# Name: Age, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["Age"], color="#6495ED", width=0.4)  # Slightly wider box

# Set y-axis limit to 70
plt.ylim(0, 70)

# Add labels and title for clarity
plt.ylabel("Age")
plt.title("Age Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical violin plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["Age"], color="#6495ED", width=0.4)  # Slightly adjusted width

# Set y-axis limit to 70
plt.ylim(0, 70)

# Add labels and title for clarity
plt.ylabel("Age")
plt.title("Age Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["Age"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")

# Display the plot
plt.show()

# %% [markdown]
# The **Age** column in the dataset is **right-skewed**, meaning that most of the age values are concentrated toward the younger ages, with a tail of higher age values. This right-skewness indicates that most individuals in the dataset are relatively young, but there are some older individuals, with a maximum age of 61. Since these high values are **valid data points** and not incorrect inputs, they could represent rare but significant cases that provide valuable insights into how obesity impacts individuals at older ages. These cases might reveal distinct patterns of obesity or health conditions specific to older individuals, which may differ from the trends observed in younger individuals.
#
# Removing these high outliers would mean losing important information that could help us understand how obesity affects older populations. Therefore, these high values should be preserved to ensure a comprehensive and accurate analysis of the dataset.

# %% [markdown]
# ## **Data Distribution : Weight**

# %%
df['Weight'].describe()
# Out:
# count    2087.000000
# mean       86.858730
# std        26.190847
# min        39.000000
# 25%        66.000000
# 50%        83.101100
# 75%       108.015907
# max       173.000000
# Name: Weight, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["Weight"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Weight")
plt.title("Weight Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Weight
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["Weight"], color="#6495ED", width=0.4)  # Slightly wider box

# Set y-axis limit to 70
plt.ylim()

# Add labels and title for clarity
plt.ylabel("Weight")
plt.title("Weight Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["Weight"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Weight")
plt.ylabel("Count")
plt.title("Weight Distribution")

# Display the plot
plt.show()

# %% [markdown]
# ## **Data Distribution : Height**

# %%
df['Height'].describe()
# Out:
# count    2087.000000
# mean        1.702674
# std         0.093186
# min         1.450000
# 25%         1.630178
# 50%         1.701584
# 75%         1.769491
# max         1.980000
# Name: Height, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["Height"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Height")
plt.title("Height Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["Height"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Height")
plt.title("Height Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["Height"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Height")
plt.ylabel("Count")
plt.title("Height Distribution")

# Display the plot
plt.show()

# %% [markdown]
# ## **Data Distribution : Family History**

# %%
df['family_history_with_overweight'].describe()
# Out:
# count     2087
# unique       2
# top        yes
# freq      1722
# Name: family_history_with_overweight, dtype: object

# %%
# Count values for Gender  
family_history_counts = df['family_history_with_overweight'].value_counts()  
family_history_percent = df['family_history_with_overweight'].value_counts(normalize=True) * 100

# %%
family_history_counts
# Out:
# family_history_with_overweight
# yes    1722
# no      365
# Name: count, dtype: int64

# %%
family_history_percent
# Out:
# family_history_with_overweight
# yes    82.510781
# no     17.489219
# Name: proportion, dtype: float64

# %%
# Define custom colors
colors = ["#6495ED", "#A9A9A9"]  # Light blue and gray

# Create bar plot with increased height
plt.figure(figsize=(6, 5.5))  # Increase height
ax = sns.barplot(x=family_history_counts.index, y=family_history_counts.values, hue=family_history_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2, p.get_height() + 20),  # Move labels above bars
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("Family History", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Family History Distribution", fontsize=14)

plt.ylim(0, family_history_counts.max() * 1.1)  # Extend y-axis limit to give space for labels
plt.show()

# %% [markdown]
# ## **Data Distribution : High Calories Food (FAVC)**

# %%
df['FAVC'].describe()
# Out:
# count     2087
# unique       2
# top        yes
# freq      1844
# Name: FAVC, dtype: object

# %%
# Count values for Gender  
favc_counts = df['FAVC'].value_counts()  
favc_percents = df['FAVC'].value_counts(normalize=True) * 100

# %%
favc_counts
# Out:
# FAVC
# yes    1844
# no      243
# Name: count, dtype: int64

# %%
favc_percents
# Out:
# FAVC
# yes    88.356493
# no     11.643507
# Name: proportion, dtype: float64

# %%
# Define custom colors
colors = ["#6495ED", "#A9A9A9"]  # Light blue and gray

# Create bar plot with increased height
plt.figure(figsize=(6, 5.5))  # Increase height
ax = sns.barplot(x=favc_counts.index, y=favc_counts.values, hue=favc_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2, p.get_height() + 20),  # Move labels above bars
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("High Calories Food (FAVC)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("High Calories Food (FAVC) Distributions", fontsize=14)

plt.ylim(0, favc_counts.max() * 1.1)  # Extend y-axis limit to give space for labels
plt.show()

# %% [markdown]
# ## **Data Distribution : Vegetable Consumption (FCVC)**

# %%
df['FCVC'].describe()
# Out:
# count    2087.000000
# mean        2.421466
# std         0.534737
# min         1.000000
# 25%         2.000000
# 50%         2.396265
# 75%         3.000000
# max         3.000000
# Name: FCVC, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["FCVC"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Vegetable Comsumtion (FCVC)")
plt.title("Vegetable Consumption (FCVC) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["FCVC"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Vegetable Comsumtion (FCVC)")
plt.title("Vegetable Consumption (FCVC) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["FCVC"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Vegetable Comsumtion (FCVC)")
plt.ylabel("Count")
plt.title("Vegetable Comsumtion (FCVC) Distribution")


# Display the plot
plt.show()

# %% [markdown]
# ## **Data Distribution : Meals Per Day (NCP)**

# %%
df['NCP'].describe()
# Out:
# count    2087.000000
# mean        2.701179
# std         0.764614
# min         1.000000
# 25%         2.697467
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: NCP, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["NCP"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Meals Per Day (NCP)")
plt.title("Meals Per Day (NCP) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["NCP"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Meals Per Day (NCP)")
plt.title("Meals Per Day (NCP) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["NCP"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Meals Per Day (NCP)")
plt.ylabel("Count")
plt.title("Meals Per Day (NCP) Distribution")


# Display the plot
plt.show()

# %% [markdown]
# ## **Data Distribution : Snack Consumptions (CAEC)**

# %%
df['CAEC'].describe()
# Out:
# count          2087
# unique            4
# top       Sometimes
# freq           1761
# Name: CAEC, dtype: object

# %%
caec_counts = df['CAEC'].value_counts()  
caec_percents = df['CAEC'].value_counts(normalize=True) * 100

# %%
caec_counts
# Out:
# CAEC
# Sometimes     1761
# Frequently     236
# Always          53
# no              37
# Name: count, dtype: int64

# %%
caec_percents
# Out:
# CAEC
# Sometimes     84.379492
# Frequently    11.308098
# Always         2.539530
# no             1.772880
# Name: proportion, dtype: float64

# %%
# Define custom colors with enough colors for each category
 # Four distinct colors
colors = ["#6495ED", "#A9A9A9", "#FF6347", "#32CD32"] 

# Create bar plot with increased height
 # Increase height
plt.figure(figsize=(6, 5.5)) 
ax = sns.barplot(x=caec_counts.index, y=caec_counts.values, hue=caec_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                 # Move labels above bars
                (p.get_x() + p.get_width() / 2, p.get_height() + 20), 
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("Snack Consumptions (CAEC)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Snack Consumptions (CAEC) Distributions", fontsize=14)

# Extend y-axis limit to give space for labels
plt.ylim(0, caec_counts.max() * 1.1)  
plt.show()

# %% [markdown]
# ## **Data Distribution : Smoker**

# %%
df['SMOKE'].describe()
# Out:
# count     2087
# unique       2
# top         no
# freq      2043
# Name: SMOKE, dtype: object

# %%
# Count values for Gender  
smoke_counts = df["SMOKE"].value_counts()  
smoke_percent = df["SMOKE"].value_counts(normalize=True) * 100

# %%
smoke_counts
# Out:
# SMOKE
# no     2043
# yes      44
# Name: count, dtype: int64

# %%
smoke_percent
# Out:
# SMOKE
# no     97.891711
# yes     2.108289
# Name: proportion, dtype: float64

# %%
# Define custom colors
colors = ["#6495ED", "#A9A9A9"]  # Light blue and gray

# Create bar plot with increased height
plt.figure(figsize=(6, 5.5))  # Increase height
ax = sns.barplot(x=smoke_counts.index, y=smoke_counts.values, hue=smoke_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2, p.get_height() + 20),  # Move labels above bars
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("Smoker", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Smoker Distribution", fontsize=14)

plt.ylim(0, smoke_counts.max() * 1.1)  # Extend y-axis limit to give space for labels
plt.show()

# %% [markdown]
# ## **Data Distribution : Water Intake (CH2O)**

# %%
df['CH2O'].describe()
# Out:
# count    2087.000000
# mean        2.004749
# std         0.608284
# min         1.000000
# 25%         1.590922
# 50%         2.000000
# 75%         2.466193
# max         3.000000
# Name: CH2O, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["CH2O"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Water Intake (CH2O)")
plt.title("Water Intake (CH2O) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["CH2O"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Water Intake (CH2O)")
plt.title("Water Intake (CH2O) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["CH2O"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Water Intake (CH2O)")
plt.ylabel("Count")
plt.title("Water Intake (CH2O) Distribution")


# Display the plot
plt.show()

# %% [markdown]
#   ## **Data Distribution : Calorie Monitoring (SCC)**

# %%
df['SCC'].describe()
# Out:
# count     2087
# unique       2
# top         no
# freq      1991
# Name: SCC, dtype: object

# %%
scc_counts = df['SCC'].value_counts()  
scc_percents = df['SCC'].value_counts(normalize=True) * 100

# %%
scc_counts
# Out:
# SCC
# no     1991
# yes      96
# Name: count, dtype: int64

# %%
scc_percents
# Out:
# SCC
# no     95.400096
# yes     4.599904
# Name: proportion, dtype: float64

# %%
# Define custom colors
colors = ["#6495ED", "#A9A9A9"]  # Light blue and gray

# Create bar plot with increased height
plt.figure(figsize=(6, 5.5))  # Increase height
ax = sns.barplot(x=scc_counts.index, y=scc_counts.values, hue=scc_counts.index, palette=colors, legend=False)

# Add value labels with better positioning
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2, p.get_height() + 20),  # Move labels above bars
                ha='center', va='bottom', fontsize=14, fontweight='bold')

# Labels and title
plt.xlabel("Calorie Monitoring (SCC)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Calorie Monitoring (SCC) Distributions", fontsize=14)

plt.ylim(0, scc_counts.max() * 1.1)  # Extend y-axis limit to give space for labels
plt.show()

# %% [markdown]
# ## **Data Distribution : Psysical Activity (FAF)**

# %%
df['FAF'].describe()
# Out:
# count    2087.000000
# mean        1.012812
# std         0.853475
# min         0.000000
# 25%         0.124505
# 50%         1.000000
# 75%         1.678102
# max         3.000000
# Name: FAF, dtype: float64

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.boxplot(y=df["FAF"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Psysical Activity (FAF)")
plt.title("Psysical Activity (FAF) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a larger vertical box plot to visualize the distribution of Age
plt.figure(figsize=(5, 5))  # Increased figure size
sns.violinplot(y=df["FAF"], color="#6495ED", width=0.4)  # Slightly wider box

# Add labels and title for clarity
plt.ylabel("Psysical Activity (FAF)")
plt.title("Psysical Activity (FAF) Distribution", fontsize=14)  # Slightly larger title font

# Display the plot
plt.show()

# %%
# Set a clean and readable style for the plot
sns.set_style("whitegrid")

# Create a histogram to visualize the distribution of Age with density estimation
plt.figure(figsize=(8, 5))
sns.histplot(df["FAF"], bins=20, kde=True, color="#6495ED")  # Light Blue

# Add labels and title for better readability
plt.xlabel("Psysical Activity (FAF)")
plt.ylabel("Count")
plt.title("Psysical Activity (FAF) Distribution")


# Display the plot
plt.show()
